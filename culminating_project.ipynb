# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
df = pd.read_excel('ABCcompany.xlsx')
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
df['Height'].head()
# Out:
# 0    2023-02-06 00:00:00
# 1    2023-06-06 00:00:00
# 2    2023-05-06 00:00:00
# 3    2023-05-06 00:00:00
# 4    2023-10-06 00:00:00
# Name: Height, dtype: object

# %%
# Replace 'Height' with random integers between 150 and 180
np.random.seed(42)  # for reproducibility
df['Height'] = np.random.randint(150, 181, size=len(df))

# Verify changes
df['Height'].head()
# Data consistency ensured — all height values are now numeric and realistic.
# Out:
# 0    156
# 1    169
# 2    178
# 3    164
# 4    160
# Name: Height, dtype: int32

# %%
team_distribution = df['Team'].value_counts()
team_percentage = round((team_distribution / len(df)) * 100, 2)

team_df = pd.DataFrame({'Team': team_distribution.index,
                        'Count': team_distribution.values,
                        'Percentage': team_percentage.values})
print("Majority of teams have 15 persons, small variation")
team_df
team_df
# Out:
# Majority of teams have 15 persons, small variation
#                       Team  Count  Percentage
# 0     New Orleans Pelicans     19        4.15
# 1        Memphis Grizzlies     18        3.93
# 2                Utah Jazz     16        3.49
# 3          Milwaukee Bucks     16        3.49
# 4          New York Knicks     16        3.49
# 5           Boston Celtics     15        3.28
# 6     Los Angeles Clippers     15        3.28
# 7       Los Angeles Lakers     15        3.28
# 8             Phoenix Suns     15        3.28
# 9         Sacramento Kings     15        3.28
# 10           Brooklyn Nets     15        3.28
# 11      Philadelphia 76ers     15        3.28
# 12         Toronto Raptors     15        3.28
# 13   Golden State Warriors     15        3.28
# 14          Indiana Pacers     15        3.28
# 15         Detroit Pistons     15        3.28
# 16     Cleveland Cavaliers     15        3.28
# 17           Chicago Bulls     15        3.28
# ...

# %%
# visualization
plt.figure(figsize=(10,5))
sns.barplot(x='Team', y='Count', data=team_df, palette='viridis')
plt.title('Employee Distribution Across Teams')
plt.xlabel('Team')
plt.ylabel('Number of Employees')
plt.xticks(rotation=90)
plt.show()
print("New Orleans Pelicans have the highest number of employees — around 19.\n Employee distribution across teams is relatively balanced,\n with only minor variations — suggesting that most teams maintain a similar workforce size, possibly due to standardized operational needs across franchises.")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8612\3164780649.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Team', y='Count', data=team_df, palette='viridis')
# New Orleans Pelicans have the highest number of employees — around 19.
#  Employee distribution across teams is relatively balanced,
#  with only minor variations — suggesting that most teams maintain a similar workforce size, possibly due to standardized operational needs across franchises.

# %%
position_distribution = df['Position'].value_counts()

plt.figure(figsize=(10,5))
sns.barplot(x=position_distribution.index, y=position_distribution.values, palette='coolwarm')
plt.title('Employee Segregation by Position')
plt.xlabel('Position')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8612\535746423.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=position_distribution.index, y=position_distribution.values, palette='coolwarm')

# %%
bins = [18, 25, 30, 35, 40, 50]
labels = ['18-25', '25-30', '30-35', '35-40', '40-50']
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

age_group_distribution = df['Age Group'].value_counts().sort_index()

plt.figure(figsize=(8,5))
sns.barplot(x=age_group_distribution.index, y=age_group_distribution.values, palette='magma')
plt.title('Predominant Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Employees')
plt.show()
print("The majority of peoples are youngsters, age between 18-35")

age_group_distribution
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8612\2085732817.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=age_group_distribution.index, y=age_group_distribution.values, palette='magma')
# The majority of peoples are youngsters, age between 18-35
# Age Group
# 18-25    154
# 25-30    182
# 30-35     90
# 35-40     29
# 40-50      3
# Name: count, dtype: int64

# %%
# By Team
team_salary = df.groupby('Team')['Salary'].sum().sort_values(ascending=False)
# By Position
position_salary = df.groupby('Position')['Salary'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,5))
sns.barplot(x=team_salary.index, y=team_salary.values, palette='plasma')
plt.title('Total Salary by Team')
plt.xlabel('Team')
plt.ylabel('Total Salary')
plt.xticks(rotation=90)
plt.show()
print(" higher salary team is Cleveland Cavaliers and lowest salary team is Philadelphia 76ers")


plt.figure(figsize=(10,5))
sns.barplot(x=position_salary.index, y=position_salary.values, palette='crest')
plt.title('Total Salary by Position')
plt.xlabel('Position')
plt.ylabel('Total Salary')
plt.xticks(rotation=0)
plt.show()

team_salary.head(1), position_salary.head(1)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8612\883199310.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=team_salary.index, y=team_salary.values, palette='plasma')
#  higher salary team is Cleveland Cavaliers and lowest salary team is Philadelphia 76ers
# C:\Users\user\AppData\Local\Temp\ipykernel_8612\883199310.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=position_salary.index, y=position_salary.values, palette='crest')
# (Team
#  Cleveland Cavaliers    106988689.0
#  Name: Salary, dtype: float64,
#  Position
#  C    466377332.0
#  Name: Salary, dtype: float64)

# %%
corr_value = df[['Age', 'Salary']].corr().iloc[0,1]
print(f"Correlation between Age and Salary = {corr_value:.2f}")

plt.figure(figsize=(6,5))
sns.scatterplot(x='Age', y='Salary', data=df, color='purple')
sns.regplot(x='Age', y='Salary', data=df, scatter=False, color='black')
plt.title('Correlation between Age and Salary')
plt.show()
print(" it is a Positive correlation because As Age increases, there is a slight possibility that Salary also increases.\n but it is also a Weak correlation because The relationship is not very strong, so it is difficult to make reliable predictions.")
# Out:
# Correlation between Age and Salary = 0.21
#  it is a Positive correlation because As Age increases, there is a slight possibility that Salary also increases.
#  but it is also a Weak correlation because The relationship is not very strong, so it is difficult to make reliable predictions.
